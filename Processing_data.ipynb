# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
all_data_csv = pd.read_csv('data/000_stroopExp_2022_Feb_21_1618.csv')
all_data_csv.drop(inplace=True, axis=0, index=0)
all_data_csv.head()
# Out:
#    stimuli_id    word color  congruent ans  trials.thisRepN  \
# 1        11.0   green  blue        0.0   b              0.0
# 2         4.0  yellow   red        0.0   r              0.0
# 3         9.0     red  blue        0.0   b              0.0
# 4        10.0    blue  blue        1.0   b              0.0
# 5         2.0    blue   red        0.0   r              0.0
#
#    trials.thisTrialN  trials.thisN  trials.thisIndex  Instruction.started  \
# 1                0.0           0.0              10.0                  NaN
# 2                1.0           1.0               3.0                  NaN
# 3                2.0           2.0               8.0                  NaN
# 4                3.0           3.0               9.0                  NaN
# 5                4.0           4.0               1.0                  NaN
#
#    ... cross.started cross.stopped  sync.started  sync.stopped participant  \
# 1  ...     16.216342     18.229158     18.195400          None           0
# ...

# %%
plt.title("Non-congruent stimulus")
hist = all_data_csv[all_data_csv['congruent'] == 0]['response.rt'].hist(bins=30)

# %%
plt.title("Congruent stimulus")
hist = all_data_csv[all_data_csv['congruent'] == 1]['response.rt'].hist(bins=30)
